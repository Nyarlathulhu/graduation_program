# %%
import pandas as pd
import numpy as np

PATH = 'E:/SEN_datasets/fashionAI_attributes_train2/'
labels = pd.read_csv(PATH+'Annotations/label.csv', names=['img_path','attr','label'])

# %%
for i in range(len(labels['label'])):
    if 'm' in labels['label'][i]:
        p = np.random.rand()
        if p <= 0.5:
            labels['label'][i] = labels['label'][i].replace('m','0')
        elif p > 0.5:
            labels['label'][i] = labels['label'][i].replace('m','1')
    labels['label'][i] = labels['label'][i].replace('n','0').replace('y','1') + 'tag'

# %%
labels
# Out:
#                                                  img_path  \
# 0       Images/collar_design_labels/b23a3fe060d71bed77...
# 1       Images/collar_design_labels/0ef580b4deabcd9fa4...
# 2       Images/collar_design_labels/87ccc33937821a97ad...
# 3       Images/collar_design_labels/26caac7d1f1b36fb9d...
# 4       Images/collar_design_labels/396ab4e7cbc6798100...
# ...                                                   ...
# 100757  Images/pant_length_labels/ce4c2d6793a4989232d4...
# 100758  Images/pant_length_labels/aeb2ed079eb041e0b8d8...
# 100759  Images/pant_length_labels/df73c36cf541ba3846c7...
# 100760  Images/pant_length_labels/c2bd3eac95bbbd28d26d...
# 100761  Images/pant_length_labels/3e6501fbcff5469d5a77...
#
#                         attr      label
# 0       collar_design_labels   10000tag
# 1       collar_design_labels   10000tag
# 2       collar_design_labels   00100tag
# 3       collar_design_labels   10000tag
# 4       collar_design_labels   01000tag
# ...                      ...        ...
# 100757    pant_length_labels  000010tag
# 100758    pant_length_labels  010000tag
# 100759    pant_length_labels  100000tag
# 100760    pant_length_labels  000001tag
# 100761    pant_length_labels  001000tag
#
# [100762 rows x 3 columns]

# %%
coat_length_labels = labels[labels['attr'] == 'coat_length_labels'].reset_index().drop(columns='index')
collar_design_labels = labels[labels['attr'] == 'collar_design_labels'].reset_index().drop(columns='index')
lapel_design_labels = labels[labels['attr'] == 'lapel_design_labels'].reset_index().drop(columns='index')
neck_design_labels = labels[labels['attr'] == 'neck_design_labels'].reset_index().drop(columns='index')
neckline_design_labels = labels[labels['attr'] == 'neckline_design_labels'].reset_index().drop(columns='index')
pant_length_labels = labels[labels['attr'] == 'pant_length_labels'].reset_index().drop(columns='index')
skirt_length_labels = labels[labels['attr'] == 'skirt_length_labels'].reset_index().drop(columns='index')
sleeve_length_labels = labels[labels['attr'] == 'sleeve_length_labels'].reset_index().drop(columns='index')

# %%
coat_length_labels.to_csv('D:/ML/BDAA/Program/data/train2_coat_length_labels.csv', index=False)
collar_design_labels.to_csv('D:/ML/BDAA/Program/data/train2_collar_design_labels.csv', index=False)
lapel_design_labels.to_csv('D:/ML/BDAA/Program/data/train2_lapel_design_labels.csv', index=False)
neck_design_labels.to_csv('D:/ML/BDAA/Program/data/train2_neck_design_labels.csv', index=False)
neckline_design_labels.to_csv('D:/ML/BDAA/Program/data/train2_neckline_design_labels.csv', index=False)
pant_length_labels.to_csv('D:/ML/BDAA/Program/data/train2_pant_length_labels.csv', index=False)
skirt_length_labels.to_csv('D:/ML/BDAA/Program/data/train2_skirt_length_labels.csv', index=False)
sleeve_length_labels.to_csv('D:/ML/BDAA/Program/data/train2_sleeve_length_labels.csv', index=False)
